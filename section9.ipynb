# %% [markdown]
# ##### Exercise 81:
#
# ###### Load the `factory.csv` file into the `df` DataFrame. This file contains two variables:
#
# ###### - `item_length`
# ###### - `item_width`
#
# ###### Using the `IsolationForest` class from the `scikit-learn` package, analyze the outliers in this dataset.
#
# ###### Set the following arguments:
#
# ###### - `n_estimators=100`
# ###### - `contamination=0.05`
# ###### - `random_state=42`
#
# ###### Reminder:
#
# ###### - `1` → normal observation
# ###### - `-1` → outlier
#
# ###### Assign a new column to the `df` DataFrame named `'outlier_flag'` that stores information whether a given sample is normal or an outlier.
#
# ###### In response, print the first ten rows of the `df` DataFrame to the console.

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest

df = pd.read_csv('factory.csv')

model = IsolationForest(n_estimators=100, contamination=0.05, random_state=42)

y_pred = model.fit_predict(df)

df['outlier_flag'] = y_pred

print(df.head(10))
# Out:
#    item_length  item_width  outlier_flag
# 0     6.206380    5.618286             1
# 1     5.756649    5.921924             1
# 2     5.576329    5.792401             1
# 3     5.304950    7.235000             1
# 4     6.764064    5.965792             1
# 5     5.668838    5.708257             1
# 6     6.241278    6.533104             1
# 7     5.951632    6.503750             1
# 8     7.192132    6.249855             1
# 9     5.999551    7.660598             1

# %% [markdown]
# ### Exercise 82:
#
# ###### The `factory.csv` file was loaded into the `df` DataFrame. This file contains two variables:
#
# ###### - `item_length`
# ###### - `item_width`
#
# ###### The `IsolationForest` class from the `scikit-learn` package was used to detect outliers in the dataset.
#
# ###### As a reminder:
#
# ###### - `1` → normal observation
# ###### - `-1` → outlier
#
# ###### A new column named `outlier_flag` was added to the `df` DataFrame, storing information whether a given sample is normal or an outlier:
#
# ```python
#    item_length  item_width  outlier_flag
# 0     6.206380    5.618286             1
# 1     5.756649    5.921924             1
# 2     5.576329    5.792401             1
# 3     5.304950    7.235000             1
# 4     6.764064    5.965792             1
# 5     5.668838    5.708257             1
# 6     6.241278    6.533104             1
# 7     5.951632    6.503750             1
# 8     7.192132    6.249855             1
# 9     5.999551    7.660598             1
# ```
#
# ###### Find the number of outliers in this dataset.
#
# ###### In response, print the result to the console.

# %%
import pandas as pd
from sklearn.ensemble import IsolationForest

df = pd.read_csv('factory.csv')

model = IsolationForest(n_estimators=100, contamination=0.05, random_state=42)

df['outlier_flag'] = model.fit_predict(df)

print(df['outlier_flag'].value_counts())
# Out:
# outlier_flag
#  1    380
# -1     20
# Name: count, dtype: int64

# %% [markdown]
# ### Exercise 83:
#
# ###### Using the `load_digits()` function from the `scikit-learn` package, load the handwritten digit dataset into the following variables:
#
# ###### - `data` — images as a NumPy array with shape `(1797, 64)`
# ###### - `target` — labels as a NumPy array with shape `(1797,)`
#
# ###### Explore this dataset.
#
# ###### You can display an image using:
#
# ```python
# import matplotlib.pyplot as plt
#
# idx = 50
# plt.imshow(data[idx].reshape(8, 8), cmap='gray_r')
# plt.title(f'Label: {target[idx]}')
# plt.show()
# ```
#
# ###### Change the value of `idx` and inspect different images.
#
# ###### As an answer, print the label for the image with:
#
# ```python
# idx = 250
# ```

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_digits

data, target = load_digits(return_X_y=True)

idx = 250
plt.imshow(data[idx].reshape(8,8), cmap='gray_r')
plt.title(f'Label:{target[idx]}')
plt.show()

print(target[idx])
# Out:
# 4

# %% [markdown]
# ### Exercise 84:
#
# ###### Using the `load_digits()` function from the `scikit-learn` package, image data was loaded into the following variables:
#
# ###### - `data` — images as a NumPy array with shape `(1797, 64)`
# ###### - `target` — labels as a NumPy array with shape `(1797,)`
#
# ###### Standardize the `data` variable.
#
# ###### Then, using the `train_test_split()` function (set `random_state=42`), split the data into training and test sets:
#
# ###### - `X_train`, `y_train`
# ###### - `X_test`, `y_test`
#
# ###### In response, print the shapes of the following arrays:
#
# ###### X_train.shape
# ###### y_train.shape
# ###### X_test.shape
# ###### y_test.shape

# %%
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

data, target = load_digits(return_X_y=True)

scaler = StandardScaler()
data = scaler.fit_transform(data)

X_train, X_test, y_train, y_test = train_test_split(data, target,random_state=42)

print(f'X_train shape: {X_train.shape}')
print(f'y_train shape: {y_train.shape}')
print(f'X_test shape: {X_test.shape}')
print(f'y_test shape: {y_test.shape}')
# Out:
# X_train shape: (1347, 64)
# y_train shape: (1347,)
# X_test shape: (450, 64)
# y_test shape: (450,)

# %% [markdown]
# ### Exercise 85:
#
# ###### Using the `load_digits()` function from the `scikit-learn` package, image data was loaded into the following variables:
#
# ###### - `data` — images as a NumPy array with shape `(1797, 64)`
# ###### - `target` — labels as a NumPy array with shape `(1797,)`
#
# ###### The `data` variable was then standardized.
#
# ###### Using the `train_test_split()` function, the data was split into training and test sets:
#
# ###### - `X_train`, `y_train`
# ###### - `X_test`, `y_test`
#
# ###### with the following shapes:
#
# ###### X_train shape: (1347, 64)
# ###### y_train shape: (1347,)
# ###### X_test shape: (450, 64)
# ###### y_test shape: (450,)
#
#
# ###### Create a multi-class classification model using the `KNeighborsClassifier` class from the `scikit-learn` package.
#
# ###### Fit the model on the training data and then evaluate it on the test data.
#
# ###### In response, print the accuracy of the model to the console.

# %%
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

data, target = load_digits(return_X_y=True)
scaler = StandardScaler()

data = data/data.max()

X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

model = KNeighborsClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

acc = model.score(X_test, y_test)

print(f'KNN accuracy: {acc:.4f}')
# Out:
# KNN accuracy: 0.9933

# %% [markdown]
# ### Exercise 86:
#
# ###### Using the `load_digits()` function from the `scikit-learn` package, image data was loaded into the following variables:
#
# ###### - `data` — images as a NumPy array with shape `(1797, 64)`
# ###### - `target` — labels as a NumPy array with shape `(1797,)`
#
# ###### The `data` variable was then standardized.
#
# ###### Using the `train_test_split()` function, the data was split into training and test sets:
#
# ###### - `X_train`, `y_train`
# ###### - `X_test`, `y_test`
#
# ###### with the following shapes:
# ###### X_train shape: (1347, 64)
# ###### y_train shape: (1347,)
# ###### X_test shape: (450, 64)
# ###### y_test shape: (450,)
#
# ###### Create a classification model using the `LogisticRegression` class from the `scikit-learn` package.
#
# ###### Fit the model on the training data and then evaluate it on the test data.
#
# ###### In response, print the accuracy of the model to the console.

# %%
import pandas as pd
from sklearn.datasets import load_digits
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

data, target = load_digits(return_X_y=True)

data = data/data.max()

X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

lreg = LogisticRegression()
lreg.fit(X_train, y_train)

acc = lreg.score(X_test,y_test)

print(f'Logistic Regression accuracy: {acc:.4f}')
# Out:
# Logistic Regression accuracy: 0.9667

# %% [markdown]
# ### Exercise 87:
#
# ###### Two files are attached to this exercise:
#
# ###### - `data_train.csv`
# ###### - `target_train.csv`
#
# ###### The `data_train.csv` file contains e-mails from two categories: **computer graphics** (`comp.graphics`) and **space** (`sci.space`).
#
# ###### The `target_train.csv` file contains the labels:
#
# ###### - `0` → `comp.graphics`
# ###### - `1` → `sci.space`
#
# ###### Load these files as DataFrame objects with the following names:
#
# ###### - `data_train`
# ###### - `target_train`
#
# ###### Explore this dataset.
#
# ###### In response, print the content of the **second element** of the `data_train` object.

# %%
import pandas as pd

data_train = pd.read_csv('data_train.csv')
target_train = pd.read_csv('target_train.csv')

print(data_train['text'].loc[1])
# Out:
# From: stephens@geod.emr.ca (Dave Stephenson)
# Subject: Re: Clementine Science Team Selected
# Nntp-Posting-Host: ngis.geod.emr.ca
# Organization: Dept. of Energy, Mines, and Resources, Ottawa
# Lines: 32
#
# nickh@CS.CMU.EDU (Nick Haines) writes:
#
# >In article <stephens.734792933@ngis> stephens@geod.emr.ca (Dave Stephenson) writes:
#
# >   Remember the first government scientist in the British Empire was
# >   the Astronomer Royal, who was paid [...] from the Department
# >   of Ordinance Budget (i.e. the military). Flamsteed House (the original
# >   RGO) was built out of Army Surplus Scrap ( A gate house at the Tower of
# >   London ?), and paid for by the sale of time expired gunpowder [...]
#
# >At the time, astronomy was vital to the military, in that navigation
# >and cartography were of primary impoortance to the military, and good
# >cartography was impossible without good astronomy.
#
# >The relevance these daysis somewhat less obvious.
#
# >Nick
#
# ...

# %% [markdown]
# ### Exercise 88:
#
# ###### Two files are attached to this exercise:
#
# ###### - `data_train.csv`
# ###### - `target_train.csv`
#
# ###### The `data_train.csv` file contains e-mails from two categories: **computer graphics** (`comp.graphics`) and **space** (`sci.space`).
#
# ###### The `target_train.csv` file contains the labels:
#
# ###### - `0` → `comp.graphics`
# ###### - `1` → `sci.space`
#
# ###### These files were loaded into the following DataFrames:
#
# ###### - `data_train`
# ###### - `target_train`
#
# ###### The first five rows of `data_train`:
#
#
# ###### 0  From: ab@nova.cc.purdue.edu (Allen B)\nSubject...
# ###### 1  From: stephens@geod.emr.ca (Dave Stephenson)\n...
# ###### 2  From: dotzlaw@ccu.umanitoba.ca (Helmut Dotzlaw...
# ###### 3  From: flb@flb.optiplan.fi ("F.Baube[tm]")\nSub...
# ###### 4  From: cchung@sneezy.phy.duke.edu (Charles Chun...
#
#
# ###### Convert the `data_train` object to a list. Assign the changes back to the `data_train` variable.
#
# ###### In response, print the length of the `data_train` list to the console.

# %%
import pandas as pd

data_train = pd.read_csv('data_train.csv')
target_train = pd.read_csv('target_train.csv')

data = []
for idx, row in data_train.iterrows():
    for item in row:
        data.append(item.split('\n'))

data_train = data

print(len(data_train))
# Out:
# 50

# %% [markdown]
# ### Exercise 89:
#
# ###### Two files are attached to this exercise:
#
# ###### - `data_train.csv`
# ###### - `target_train.csv`
#
# ###### The `data_train.csv` file contains e-mails from two categories: **computer graphics** (`comp.graphics`) and **space** (`sci.space`).
#
# ###### The `target_train.csv` file contains the labels:
#
# ###### - `0` → `comp.graphics`
# ###### - `1` → `sci.space`
#
# ###### These files were loaded into the following DataFrames:
#
# ###### - `data_train`
# ###### - `target_train`
#
# ###### Some processing of `data_train` and `target_train` was performed.
#
# ###### Using the `CountVectorizer` class from the `scikit-learn` package, vectorize the text from the `data_train` list and assign it to the variable:
#
# ###### - `data_train_vectorized`
#
# ###### In response, print the shape of the resulting sparse matrix to the console.

# %%
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer


data_train = pd.read_csv('data_train.csv')
target_train = pd.read_csv('target_train.csv')

data_train = data_train['text'].tolist()
target_train = target_train.values.ravel()

vec = CountVectorizer()
data_train_vectorized = vec.fit_transform(data_train)

print(data_train_vectorized.shape)
# Out:
# (50, 3225)

# %% [markdown]
# ### Exercise 90:
#
# ###### Two files are attached to this exercise:
#
# ###### - `data_train.csv`
# ###### - `target_train.csv`
#
# ###### The `data_train.csv` file contains e-mails from two categories: **computer graphics** (`comp.graphics`) and **space** (`sci.space`).
#
# ###### The `target_train.csv` file contains the labels:
#
# ###### - `0` → `comp.graphics`
# ###### - `1` → `sci.space`
#
# ###### These files were loaded into the following DataFrames:
#
# ###### - `data_train`
# ###### - `target_train`
#
# ###### Some processing of `data_train` and `target_train` was performed.
#
# ###### The `CountVectorizer` class from the `scikit-learn` package was used to vectorize the text (stored in `data_train_vectorized`).
#
# ###### Using the `MultinomialNB` class, create a text document classification model. Train the model based on:
#
# ###### - `data_train_vectorized`
# ###### - `target_train`
#
# ###### Then classify the following sentences:
#
# ###### - `"The graphic designer requires a good processor to work."`
# ###### - `"Flights into space."`
#
# ###### In response, print the result to the console.

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer

from sklearn.naive_bayes import MultinomialNB

data_train = pd.read_csv('data_train.csv')
target_train = pd.read_csv('target_train.csv')

data_train = data_train['text'].tolist()
target_train = target_train.values.ravel()

categories = ['comp.graphics', 'sci.space']

vectorizer = CountVectorizer()
data_train_vectorized = vectorizer.fit_transform(data_train)

model = MultinomialNB()

model.fit(data_train_vectorized, target_train)

docs = ["The graphic designer requires a good processor to work.",
        "Flights into space."]

data_new = vectorizer.transform(docs)

data_pred = model.predict(data_new)

for doc, category in zip(docs, data_pred):
    print(f'\'{doc}\' => {categories[category]}')
# Out:
# 'The graphic designer requires a good processor to work.' => comp.graphics
# 'Flights into space.' => sci.space
